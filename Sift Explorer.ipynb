# %%
import cv2
from mfeat import local
import numpy as np
import matplotlib.pyplot as plt

# %%
empt = np.empty((4,4))

# %%
nplist= [blah,bleb]

# %%
nplist.append(blah)

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/nils/CC/afm-cnn/data/raw/afm_clean.csv')
df
# Out:
#         id noise secondaryNoise fiber  \
# 0        1     l            NaN     n
# 1        2     l            NaN     n
# 2        3     l            NaN     n
# 3        4     l            NaN     n
# 4        5     l            NaN     n
# 5        6     l            NaN     n
# 6        7     c            NaN     n
# 7        8     c            NaN     n
# 8        9     c            NaN     n
# 9       10     l            NaN     n
# 10      11     c            NaN     n
# 11      12     l            NaN     n
# 12      13     c            NaN     n
# 13      14     c            NaN     n
# 14      15     l            NaN     n
# 15      16     c            NaN     n
# 16      17     c            NaN     n
# 17      18     c            NaN     n
# 18      19     c            NaN     n
# 19      20     n            NaN     n
# 20      21     c            NaN     n
# 21      22     c            NaN     n
# 22      23     n            NaN     n
# ...

# %%
ll = [0,1,2,3,4,5]
ll[[1,3,4]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-c0856d3626bd> in <module>()
#       1 ll = [0,1,2,3,4,5]
# ----> 2 ll[[1,3,4]]
#
# TypeError: list indices must be integers or slices, not list

# %%
np.unique(df.noise)
# Out:
# array(['b', 'c', 'g', 'l', 'n', 'p', 's', 'w'], dtype=object)

# %%
np.array(nplist).shape
# Out:
# (3, 4, 4)

# %%
nplist.append(blah)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-2d17ff4c1113> in <module>()
# ----> 1 nplist.append(blah)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
blah=np.ones((4,4))
bleb = np.zeros((4,4))
bloob = np.dstack([blah,bleb])

# %%
blooob = np.dstack([bloob,blah])
blooob.shape
# Out:
# (4, 4, 3)

# %%
bluuub=np.load('/Users/nils/Desktop/test.npy')

# %%
np.save('/Users/nils/Desktop/test',blooob)

# %%
np.savetxt('/Users/nils/Desktop/test.txt',blooob,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda/envs/pyTen/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1253                 try:
# -> 1254                     fh.write(asbytes(format % tuple(row) + newline))
#    1255                 except TypeError:
#
# TypeError: only length-1 arrays can be converted to Python scalars
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e7f32d36fad8> in <module>()
# ----> 1 np.savetxt('/Users/nils/Desktop/test.txt',blooob)
#
# /anaconda/envs/pyTen/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
# ...

# %%
file = '/Users/nils/CC/afm-cnn/data/raw/55.tif'

# %%
oct_kp[:,0]
# Out:
# array([   3.14837503,  146.39285278,    0.42985952,    0.88625395,
#          -0.88625395,    0.42985952])

# %%
def oct2cv(oct_kp):
    cv_kp = cv.KeyPoint(x, y, _size[, _angle[, _response[, _octave[, _class_id]]]]	)
# Out:
# <KeyPoint 0x121e2f660>

# %%
img=cv2.imread(file)
if img.shape[2]>1:
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# oct_kp, oct_feats = local.sparse_sift(gray)

cvsift = cv2.xfeatures2d.SIFT_create(contrastThreshold=0.02)
kp, cv_feats = cvsift.detectAndCompute(gray,None)

# %matplotlib notebook
sift_img=cv2.drawKeypoints(gray.copy(),kp,img.copy(),flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.figure()
plt.imshow(sift_img)
# Out:
# <img src="data:image/png;base64,..." width="639.7833333333333">

# %%
# %matplotlib notebook
oct_img=cv2.drawKeypoints(gray.copy(),oct_kp,img.copy(),flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.figure()
plt.imshow(oct_img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ab4618e7cb3b> in <module>()
#       1 get_ipython().magic('matplotlib notebook')
# ----> 2 oct_img=cv2.drawKeypoints(gray.copy(),oct_kp,img.copy(),flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
#       3 plt.figure()
#       4 plt.imshow(oct_img)
#
# TypeError: Expected cv::KeyPoint for argument 'keypoints'
